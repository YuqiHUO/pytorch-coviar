# %%
import numpy as np
from coviar import load
data = 'coviar.mp4'
i = load(data, 1, 0, 0, False)

# %%
import matplotlib.pyplot as plt
#import cv2
# %matplotlib inline
import PIL.Image as Image
#cv2.imwrite('i1.jpg', i)
plt.imshow(i[...,::-1])

# %%
# Out:
# (3,)
